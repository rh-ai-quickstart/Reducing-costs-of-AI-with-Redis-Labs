# %% [markdown]
# ![Redis](https://redis.io/wp-content/uploads/2024/04/Logotype.svg?auto=webp&quality=85,75&width=120)
# # Vector Search with RedisVL
#
# ## Let's Begin!
# <a href="https://colab.research.google.com/github/redis-developer/redis-ai-resources/blob/main/python-recipes/vector-search/01_redisvl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Prepare data
#
# In this examples we will load a list of movies with the following attributes: `title`, `rating`, `description`, and `genre`.
#
# We will embed the movie description so that user's can search for movies that best match the kind of movie that they're looking for.
#
# **If you are running this notebook locally**, FYI you may not need to perform this step at all.

# %%
# NBVAL_SKIP
# !git clone https://github.com/redis-developer/redis-ai-resources.git temp_repo
# !mv temp_repo/python-recipes/vector-search/resources .
# !rm -rf temp_repo
# Out:
# Cloning into 'temp_repo'...
# remote: Enumerating objects: 669, done.
# remote: Counting objects: 100% (320/320), done.
# remote: Compressing objects: 100% (207/207), done.
# remote: Total 669 (delta 219), reused 141 (delta 112), pack-reused 349 (from 2)
# Receiving objects: 100% (669/669), 57.77 MiB | 20.61 MiB/s, done.
# Resolving deltas: 100% (287/287), done.

# %% [markdown]
# ## Packages

# %%
# %pip install -q "redisvl>=0.11.0" sentence-transformers pandas nltk

# %% [markdown]
# ## Install Redis Stack
#
# Later in this tutorial, Redis will be used to store, index, and query vector
# embeddings created from PDF document chunks. **We need to make sure we have a Redis
# instance available.
#
# #### For Colab
# Use the shell script below to download, extract, and install [Redis Stack](https://redis.io/docs/getting-started/install-stack/) directly from the Redis package archive.

# %%
# NBVAL_SKIP
# %%sh
curl -fsSL https://packages.redis.io/gpg | sudo gpg --dearmor -o /usr/share/keyrings/redis-archive-keyring.gpg
echo "deb [signed-by=/usr/share/keyrings/redis-archive-keyring.gpg] https://packages.redis.io/deb $(lsb_release -cs) main" | sudo tee /etc/apt/sources.list.d/redis.list
sudo apt-get update  > /dev/null 2>&1
sudo apt-get install redis-stack-server  > /dev/null 2>&1
redis-stack-server --daemonize yes

# %% [markdown]
# #### For Alternative Environments
# There are many ways to get the necessary redis-stack instance running
# 1. On cloud, deploy a [FREE instance of Redis in the cloud](https://redis.com/try-free/). Or, if you have your
# own version of Redis Enterprise running, that works too!
# 2. Per OS, [see the docs](https://redis.io/docs/latest/operate/oss_and_stack/install/install-stack/)
# 3. With docker: `docker run -d --name redis-stack-server -p 6379:6379 redis/redis-stack-server:latest`

# %% [markdown]
# ### Define the Redis Connection URL
#
# By default this notebook connects to the local instance of Redis Stack. **If you have your own Redis Enterprise instance** - replace REDIS_PASSWORD, REDIS_HOST and REDIS_PORT values with your own.

# %%
import os
import warnings

warnings.filterwarnings('ignore')

# Replace values below with your own if using Redis Cloud instance
REDIS_HOST = os.getenv("REDIS_HOST", "localhost") # ex: "redis-18374.c253.us-central1-1.gce.cloud.redislabs.com"
REDIS_PORT = os.getenv("REDIS_PORT", "6379")      # ex: 18374
REDIS_PASSWORD = os.getenv("REDIS_PASSWORD", "")  # ex: "1TNxTEdYRDgIDKM2gDfasupCADXXXX"

# If SSL is enabled on the endpoint, use rediss:// as the URL prefix
REDIS_URL = f"redis://:{REDIS_PASSWORD}@{REDIS_HOST}:{REDIS_PORT}"

# %% [markdown]
# ### Create redis client

# %%
from redis import Redis

client = Redis.from_url(REDIS_URL)
client.ping()
# Out:
# True

# %%
#client.flushall()
# Out:
# True

# %% [markdown]
# ### Load Movies Dataset

# %%
import pandas as pd
import numpy as np
import json

df = pd.read_json("resources/movies.json")
print("Loaded", len(df), "movie entries")

df.head()
# Out:
# Loaded 20 movie entries
#    id              title   genre  rating  \
# 0   1  Explosive Pursuit  action       7
# 1   2            Skyfall  action       8
# 2   3   Fast & Furious 9  action       6
# 3   4        Black Widow  action       7
# 4   5          John Wick  action       8
#
#                                          description
# 0  A daring cop chases a notorious criminal acros...
# 1  James Bond returns to track down a dangerous n...
# 2  Dom and his crew face off against a high-tech ...
# 3  Natasha Romanoff confronts her dark past and f...
# 4  A retired hitman seeks vengeance against those...

# %%
from redisvl.utils.vectorize import HFTextVectorizer
from redisvl.extensions.cache.embeddings import EmbeddingsCache

os.environ["TOKENIZERS_PARALLELISM"] = "false"


hf = HFTextVectorizer(
    model="sentence-transformers/all-MiniLM-L6-v2",
    cache=EmbeddingsCache(
        name="embedcache",
        ttl=600,
        redis_client=client,
    )
)
# Out:
# 08:53:13 sentence_transformers.SentenceTransformer INFO   Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# 08:53:14 sentence_transformers.SentenceTransformer INFO   Use pytorch device_name: mps
# Batches: 100%|██████████| 1/1 [00:01<00:00,  1.42s/it]

# %%
# Generate vectors
df["vector"] = hf.embed_many(df["description"].tolist(), as_buffer=True)

df.head()
# Out:
# Batches: 100%|██████████| 1/1 [00:00<00:00,  5.26it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 11.06it/s]
#    id              title   genre  rating  \
# 0   1  Explosive Pursuit  action       7
# 1   2            Skyfall  action       8
# 2   3   Fast & Furious 9  action       6
# 3   4        Black Widow  action       7
# 4   5          John Wick  action       8
#
#                                          description  \
# 0  A daring cop chases a notorious criminal acros...
# 1  James Bond returns to track down a dangerous n...
# 2  Dom and his crew face off against a high-tech ...
# 3  Natasha Romanoff confronts her dark past and f...
# 4  A retired hitman seeks vengeance against those...
#
#                                               vector
# 0  b'\x8af|=]a\n;\xc0\x91\xb7;5\xcb~\xbd)e\xce\xb...
# 1  b'\x96D\x9e\xbdJ\x9b\x89\xbc\xd3\x16\x95\xbc\x...
# 2  b',\xa5\xc7\xbc\xfe,\xa2=\x06\x19H\xbcK\xc6t\x...
# 3  b'q\xeb\x85\xbd\x02\xcdo\xbdc\xe8\xc2\xbbP\xcf...
# 4  b'\x1e<x\xbb\xfb.\xc5=\xe1\x85:;\xc1\xd0\x94<\...

# %% [markdown]
# ## Define Redis index schema

# %%
from redisvl.schema import IndexSchema
from redisvl.index import SearchIndex


index_name = "movies"

schema = IndexSchema.from_dict({
  "index": {
    "name": index_name,
    "prefix": index_name,
    "storage_type": "hash"
  },
  "fields": [
    {
        "name": "title",
        "type": "text",
    },
    {
        "name": "description",
        "type": "text",
    },
    {
        "name": "genre",
        "type": "tag",
        "attrs": {
            "sortable": True
        }
    },
    {
        "name": "rating",
        "type": "numeric",
        "attrs": {
            "sortable": True
        }
    },
    {
        "name": "vector",
        "type": "vector",
        "attrs": {
            "dims": 384,
            "distance_metric": "cosine",
            "algorithm": "flat",
            "datatype": "float32"
        }
    }
  ]
})


index = SearchIndex(schema, client)
index.create(overwrite=True, drop=True)

# %%
# !rvl index info -i movies -u {REDIS_URL}
# Out:
# Index Information:
# ╭──────────────┬────────────────┬────────────┬─────────────────┬────────────╮
# │ Index Name   │ Storage Type   │ Prefixes   │ Index Options   │   Indexing │
# ├──────────────┼────────────────┼────────────┼─────────────────┼────────────┤
# │ movies       │ HASH           │ ['movies'] │ []              │          0 │
# ╰──────────────┴────────────────┴────────────┴─────────────────┴────────────╯
# Index Fields:
# ╭─────────────┬─────────────┬─────────┬────────────────┬────────────────┬────────────────┬────────────────┬────────────────┬────────────────┬─────────────────┬────────────────╮
# │ Name        │ Attribute   │ Type    │ Field Option   │ Option Value   │ Field Option   │ Option Value   │ Field Option   │   Option Value │ Field Option    │ Option Value   │
# ├─────────────┼─────────────┼─────────┼────────────────┼────────────────┼────────────────┼────────────────┼────────────────┼────────────────┼─────────────────┼────────────────┤
# │ title       │ title       │ TEXT    │ WEIGHT         │ 1              │                │                │                │                │                 │                │
# │ description │ description │ TEXT    │ WEIGHT         │ 1              │                │                │                │                │                 │                │
# │ genre       │ genre       │ TAG     │ SEPARATOR      │ ,              │                │                │                │                │                 │                │
# │ rating      │ rating      │ NUMERIC │ SORTABLE       │ UNF            │                │                │                │                │                 │                │
# │ vector      │ vector      │ VECTOR  │ algorithm      │ FLAT           │ data_type      │ FLOAT32        │ dim            │            384 │ distance_metric │ COSINE         │
# ╰─────────────┴─────────────┴─────────┴────────────────┴────────────────┴────────────────┴────────────────┴────────────────┴────────────────┴─────────────────┴────────────────╯

# %% [markdown]
# ## Populate index

# %%
index.load(df.to_dict(orient="records"))
# Out:
# ['movies:01KNVQ8MH8VB3CZF0K1DCK6E4P',
#  'movies:01KNVQ8MH85N0M6SZN5EVYP2N7',
#  'movies:01KNVQ8MH8PB65SP82BHJ8D7WF',
#  'movies:01KNVQ8MH809XYKKK803903EJZ',
#  'movies:01KNVQ8MH8W3CJV955DJGQ3Y29',
#  'movies:01KNVQ8MH80XWMPW8AKRJ8CWHS',
#  'movies:01KNVQ8MH84SASS3HGE86D7BNM',
#  'movies:01KNVQ8MH84J3W60V1XDYC7S01',
#  'movies:01KNVQ8MH803G1VKYEMYV3S84G',
#  'movies:01KNVQ8MH8Y6GSSMK57MGRKE1B',
#  'movies:01KNVQ8MH8DERHA3TYTY5JRR42',
#  'movies:01KNVQ8MH8PVKQKDNXPSJBNK0E',
#  'movies:01KNVQ8MH86YT2GD63XJDAXHSH',
#  'movies:01KNVQ8MH84V9R1JYQ9J8C926M',
#  'movies:01KNVQ8MH857FA2G3M45GFAHG4',
#  'movies:01KNVQ8MH854TV5QDNRD65YZ6Z',
#  'movies:01KNVQ8MH8D3CPMGXYHH8996NZ',
#  'movies:01KNVQ8MH8QM977BX5CAAMEW27',
#  'movies:01KNVQ8MH89SAXEBEAEP7J25PR',
#  'movies:01KNVQ8MH88GY44RT5R4Y3NSFN']

# %% [markdown]
# ## Search techniques
#
# ### Standard vector search

# %%
from redisvl.query import VectorQuery

user_query = "High tech and action packed movie"

embedded_user_query = hf.embed(user_query)

vec_query = VectorQuery(
    vector=embedded_user_query,
    vector_field_name="vector",
    num_results=3,
    return_fields=["title", "genre"],
    return_score=True,
)

result = index.query(vec_query)
pd.DataFrame(result)
# Out:
# Batches: 100%|██████████| 1/1 [00:00<00:00,  8.34it/s]
#                                   id vector_distance               title  \
# 0  movies:01KNVQ8MH8PB65SP82BHJ8D7WF   0.64973795414    Fast & Furious 9
# 1  movies:01KNVQ8MH80XWMPW8AKRJ8CWHS  0.763235092163  Mad Max: Fury Road
# 2  movies:01KNVQ8MH8PVKQKDNXPSJBNK0E  0.792449653149      The Lego Movie
#
#     genre
# 0  action
# 1  action
# 2  comedy

# %% [markdown]
# ### Vector search with filters
#
# Redis allows you to combine filter searches on fields within the index object allowing us to create more specific searches.

# %% [markdown]
# Search for top 3 movies specifically in the action genre:

# %%
from redisvl.query.filter import Tag

tag_filter = Tag("genre") == "action"

vec_query.set_filter(tag_filter)

result=index.query(vec_query)
pd.DataFrame(result)
# Out:
#                                   id vector_distance               title  \
# 0  movies:01JSHDN7Q4GG029M45HQY8Q5T2   0.64973795414    Fast & Furious 9
# 1  movies:01JSHDN7Q40QYH6Q6TD7ES4TSG  0.763235092163  Mad Max: Fury Road
# 2  movies:01JSHDN7Q4AHFG0J8D7Q8QS1BG  0.796153008938   Explosive Pursuit
#
#     genre
# 0  action
# 1  action
# 2  action

# %% [markdown]
# Search for top 3 movies specifically in the action genre with ratings at or above a 7:

# %%
from redisvl.query.filter import Num

# build combined filter expressions
tag_filter = Tag("genre") == "action"
num_filter = Num("rating") >= 7
combined_filter = tag_filter & num_filter

# build vector query
vec_query = VectorQuery(
    vector=embedded_user_query,
    vector_field_name="vector",
    num_results=3,
    return_fields=["title", "rating", "genre"],
    return_score=True,
    filter_expression=combined_filter
)

result = index.query(vec_query)
pd.DataFrame(result)
# Out:
#                                   id vector_distance               title  \
# 0  movies:01JSHDN7Q40QYH6Q6TD7ES4TSG  0.763235092163  Mad Max: Fury Road
# 1  movies:01JSHDN7Q4AHFG0J8D7Q8QS1BG  0.796153008938   Explosive Pursuit
# 2  movies:01JSHDN7Q481PGAEDBX0QG75RP   0.87649422884           Inception
#
#   rating   genre
# 0      8  action
# 1      7  action
# 2      9  action

# %% [markdown]
# Search with full text search for movies that directly mention "criminal mastermind" in the description:

# %%
from redisvl.query.filter import Text

text_filter = Text("description") % "criminal mastermind"

vec_query = VectorQuery(
    vector=embedded_user_query,
    vector_field_name="vector",
    num_results=3,
    return_fields=["title", "rating", "genre", "description"],
    return_score=True,
    filter_expression=text_filter
)

result = index.query(vec_query)
pd.DataFrame(result)
# Out:
#                                   id vector_distance            title rating  \
# 0  movies:01JSHDN7Q4W1NYVVAEBTV91X9X  0.827254056931    Despicable Me      7
# 1  movies:01JSHDN7Q4ZG1SBF02A9SMV6DB  0.990856587887  The Dark Knight      9
#
#     genre                                        description
# 0  comedy  When a criminal mastermind uses a trio of orph...
# 1  action  Batman faces off against the Joker, a criminal...

# %% [markdown]
# Vector search with wildcard text match:

# %%
text_filter = Text("description") % "crim*"

vec_query = VectorQuery(
    vector=embedded_user_query,
    vector_field_name="vector",
    num_results=3,
    return_fields=["title", "rating", "genre", "description"],
    return_score=True,
    filter_expression=text_filter
)

result = index.query(vec_query)
pd.DataFrame(result)
# Out:
#                                   id vector_distance              title  \
# 0  movies:01JSHDN7Q4AHFG0J8D7Q8QS1BG  0.796153008938  Explosive Pursuit
# 1  movies:01JSHDN7Q4JARJS5Q4HQZ90RRX  0.807471334934    The Incredibles
# 2  movies:01JSHDN7Q4W1NYVVAEBTV91X9X  0.827254056931      Despicable Me
#
#   rating   genre                                        description
# 0      7  action  A daring cop chases a notorious criminal acros...
# 1      8  comedy  A family of undercover superheroes, while tryi...
# 2      7  comedy  When a criminal mastermind uses a trio of orph...

# %% [markdown]
# Vector search with fuzzy match filter
#
# > Note: fuzzy match is based on Levenshtein distance. Therefore, "hero" might return result for "her" as an example.
#
# See docs for more info https://redis.io/docs/latest/develop/interact/search-and-query/advanced-concepts/query_syntax/

# %%
text_filter = Text("description") % "%hero%"

vec_query = VectorQuery(
    vector=embedded_user_query,
    vector_field_name="vector",
    num_results=3,
    return_fields=["title", "rating", "genre", "description"],
    return_score=True,
    filter_expression=text_filter
)

result = index.query(vec_query)
pd.DataFrame(result)
# Out:
#                                   id vector_distance                 title  \
# 0  movies:01JSHDN7Q4QFMK2MGNKJHTFT9E  0.889985799789           Black Widow
# 1  movies:01JSHDN7Q4031K8AS44WJ3J9ZR  0.893866717815          The Avengers
# 2  movies:01JSHDN7Q4W3ZWAJGWT7YQPKVR  0.943198204041  The Princess Diaries
#
#   rating   genre                                        description
# 0      7  action  Natasha Romanoff confronts her dark past and f...
# 1      8  action  Earth's mightiest heroes come together to stop...
# 2      6  comedy  Mia Thermopolis has just found out that she is...

# %% [markdown]
# ### Range queries
#
# Range queries allow you to set a pre defined distance "threshold" for which we want to return documents. This is helpful when you only want documents with a certain "radius" from the search query.

# %%
from redisvl.query import RangeQuery

user_query = "Family friendly fantasy movies"

embedded_user_query = hf.embed(user_query)

range_query = RangeQuery(
    vector=embedded_user_query,
    vector_field_name="vector",
    return_fields=["title", "rating", "genre"],
    return_score=True,
    distance_threshold=0.8  # find all items with a semantic distance of less than 0.8
)

result = index.query(range_query)
pd.DataFrame(result)
# Out:
#                                   id vector_distance            title rating  \
# 0  movies:01JSHDN7Q4JARJS5Q4HQZ90RRX  0.644702494144  The Incredibles      8
# 1  movies:01JSHDN7Q4QFMK2MGNKJHTFT9E  0.747987031937      Black Widow      7
# 2  movies:01JSHDN7Q4W1NYVVAEBTV91X9X  0.750915527344    Despicable Me      7
# 3  movies:01JSHDN7Q4Y009NXBPM25YDZDV  0.751298904419            Shrek      8
# 4  movies:01JSHDN7Q4W21S96KMMBZ2X6KY  0.761669397354   Monsters, Inc.      8
# 5  movies:01JSHDN7Q4H6JSC5Y2FKT7SWJ8  0.778580129147          Aladdin      8
#
#     genre
# 0  comedy
# 1  action
# 2  comedy
# 3  comedy
# 4  comedy
# 5  comedy

# %% [markdown]
# Like the queries above, we can also chain additional filters and conditional operators with range queries. The following adds an `and` condition that returns vector search within the defined range and with a rating at or above 8.

# %%
range_query = RangeQuery(
    vector=embedded_user_query,
    vector_field_name="vector",
    return_fields=["title", "rating", "genre"],
    distance_threshold=0.8
)

numeric_filter = Num("rating") >= 8

range_query.set_filter(numeric_filter)

# in this case we want to do a simple filter search or the vector so we execute as a joint filter directly
result = index.query(range_query)
pd.DataFrame(result)
# Out:
#                                   id vector_distance            title rating  \
# 0  movies:01JSHDN7Q4JARJS5Q4HQZ90RRX  0.644702494144  The Incredibles      8
# 1  movies:01JSHDN7Q4Y009NXBPM25YDZDV  0.751298904419            Shrek      8
# 2  movies:01JSHDN7Q4W21S96KMMBZ2X6KY  0.761669397354   Monsters, Inc.      8
# 3  movies:01JSHDN7Q4H6JSC5Y2FKT7SWJ8  0.778580129147          Aladdin      8
#
#     genre
# 0  comedy
# 1  comedy
# 2  comedy
# 3  comedy

# %% [markdown]
# ### Full text search

# %%
from redisvl.query import TextQuery

user_query = "High tech, action packed, superheros fight scenes"

text_query = TextQuery(
    text=user_query,
    text_field_name="description",
    text_scorer="BM25STD",
    num_results=20,
    return_fields=["title", "description"],
)

result = index.query(text_query)[:4]
pd.DataFrame(result)[["title", "score"]]
# Out:
#                title     score
# 0   Fast & Furious 9  5.157032
# 1    The Incredibles  4.022877
# 2  Explosive Pursuit  2.335427
# 3          Toy Story  1.630097

# %% [markdown]
# ### Hybrid search

# %%
from redisvl.query import AggregateHybridQuery

hybrid_query = AggregateHybridQuery(
    text=user_query,
    text_field_name="description",
    text_scorer="BM25",
    vector=embedded_user_query,
    vector_field_name="vector",
    alpha=0.7,
    num_results=20,
    return_fields=["title", "description"],
)

result = index.query(hybrid_query)[:4]
pd.DataFrame(result)[["title", "vector_similarity", "text_score", "hybrid_score"]]
# Out:
#               title vector_similarity      text_score    hybrid_score
# 0   The Incredibles    0.677648752928  0.398671082609  0.593955451832
# 1  Fast & Furious 9    0.537397742271  0.498220622181  0.525644606244
# 2         Toy Story    0.553009659052  0.213523123792  0.451163698474
# 3       Black Widow    0.626006484032               0  0.438204538822

# %% [markdown]
# ### Next steps
#
# For more query examples with redisvl: [see here](https://github.com/redis/redis-vl-python/blob/main/docs/user_guide/02_hybrid_queries.ipynb)

# %%
# clean up!
index.delete()
